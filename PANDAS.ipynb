# %% [markdown]
# ### PANDAS
#
# PANDAS IS A POWERULL PYTHON LIBRARY FOR MANIPULAtion array analysis of data
# its a open sours library
# fast (built on top of numpy),flexible(different resoures),productive library

# %% [markdown]
# Install

# %%
! pip install pandas
# Out:
# Access is denied.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ####series - one dimecsional array a9data structure)with label

# %%
l1 = [1,2,3,4,5]
type(l1)
# Out:
# list

# %%
s = pd.Series(l1,index= ["a","b","c","d","e"],name = "my series")

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# NOTE : Index in series imuutable(cant change)

# %%
s.index[0] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s.index[0] = 'z'
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
s.index[0]
# Out:
# 'a'

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
# changing the index of a pandas series
s.rename(index={'b':'y'})
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %%
# changing the index of a pandas series
s.rename(index={'b':'y'},inplace=True)

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %% [markdown]
# ###DataFrame - Its a 2d array (just like tables)

# %% [markdown]
# #rows and colums

# %% [markdown]
# dict1 = {'name':['virat','rohit','surabh','vedhu','bhum'],
#         'age':[34,65,20,30,33],
#         'marks':[84,56,76,21,97],
#         'role':['batsman','all rounder','boller','wiket keeper','bower']
# }
# pd.dataframe(dict1)

# %%
dict1 = {'name':['virat','rohit','surabh','vedhu','virat'],
        'age':[34,65,20,30,33],
        'marks':[84,56,76,21,97],
        'role':['batsman','all rounder','boller','wiket keeper','bower']
}
df = pd.DataFrame(dict1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      name  age  marks          role
# 0   virat   34     84       batsman
# 1   rohit   65     56   all rounder
# 2  surabh   20     76        boller
# 3   vedhu   30     21  wiket keeper
# 4    bhum   33     97         bower

# %%
df.count()
# Out:
# name     5
# age      5
# marks    5
# role     5
# dtype: int64

# %%
len(df)
# Out:
# 5

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'role'], dtype='object')

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df['name'].value_counts()
# Out:
# name
# virat     2
# rohit     1
# surabh    1
# vedhu     1
# Name: count, dtype: int64
